# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjali-ssshh/github-slideshow/blob/main/dataprep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import Pandas
# import numpy -> from numpy import Series and DataFrame

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %% [markdown]
# Create series of n integeres using np.arrange(n) function

# %%
Series_obj=Series(np.arange(8), index=['row1', 'row2','row3','row4','row5','row6','row7','row8'])
Series_obj
# Out:
# row1    0
# row2    1
# row3    2
# row4    3
# row5    4
# row6    5
# row7    6
# row8    7
# dtype: int64

# %% [markdown]
# Retrieve object at row 5 using label index

# %%
Series_obj['row5']

# %% [markdown]
# Retrieve object at three row positions

# %%
Series_obj[[0,1,5]]

# %% [markdown]
# Create dataframe
# 1. set the seed
# 2. generate random numbers using np.random.rand()
# 3. Create index for the rows and cols

# %%
np.random.seed(25)
df_obj=DataFrame(np.random.rand(36).reshape((6,6)),
                        )
df_obj
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  0.113041
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  0.699186
# 3  0.366395  0.836375  0.481343  0.516502  0.383048  0.997541
# 4  0.514244  0.559053  0.034450  0.719930  0.421004  0.436935
# 5  0.281701  0.900274  0.669612  0.456069  0.289804  0.525819

# %% [markdown]
# Retreive values from rows and cols of the dataframe using .loc method

# %%
df_obj.loc[['row2','row5'],['col5','col2']]
# Out:
#           col5      col2
# row2  0.402366  0.437611
# row5  0.421004  0.559053

# %% [markdown]
# **Data Slicing**
# colon seprated index labels

# %%
Series_obj['row2':'row5']
# Out:
# row2    1
# row3    2
# row4    3
# row5    4
# dtype: int64

# %% [markdown]
# **Comparison with scalars**
# using <,>,=

# %%
df_obj>.2
# Out:
#       col1  col2   col3   col4  col5   col6
# row1  True  True   True  False  True  False
# row2  True  True   True   True  True  False
# row3  True  True  False   True  True   True
# row4  True  True   True   True  True   True
# row5  True  True  False   True  True   True
# row6  True  True   True   True  True   True

# %% [markdown]
# **Filtering with Scalars**

# %%
Series_obj[Series_obj>5]
# Out:
# row7    6
# row8    7
# dtype: int64

# %% [markdown]
# **Setting values with scalars**

# %%
Series_obj[['row1','row2']]=2
Series_obj
# Out:
# row1    2
# row2    2
# row3    2
# row4    3
# row5    4
# row6    5
# row7    6
# row8    7
# dtype: int64

# %% [markdown]
# Finding out what data is missing
# -using np.nan method

# %%
missing=np.nan
S_obj=Series(['row1','row2', missing,'row4'])
S_obj
# Out:
# 0    row1
# 1    row2
# 2     NaN
# 3    row4
# dtype: object

# %% [markdown]
# isnull method

# %%
S_obj.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %% [markdown]
# Filling the missing values

# %%
df_obj.loc[3:5,0]=missing
df_obj.loc[1:4,5]=missing
df_obj
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366       NaN
# 2  0.447031  0.585445  0.161985  0.520719  0.326051       NaN
# 3       NaN  0.836375  0.481343  0.516502  0.383048       NaN
# 4       NaN  0.559053  0.034450  0.719930  0.421004       NaN
# 5       NaN  0.900274  0.669612  0.456069  0.289804  0.525819

# %% [markdown]
# Fill the missing values

# %%
filled_df=df_obj.fillna(1)
filled_df
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  1.000000
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  1.000000
# 3  1.000000  0.836375  0.481343  0.516502  0.383048  1.000000
# 4  1.000000  0.559053  0.034450  0.719930  0.421004  1.000000
# 5  1.000000  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
filled_df=df_obj.fillna({0:1.25,5:1.5})
filled_df
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  1.500000
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  1.500000
# 3  1.250000  0.836375  0.481343  0.516502  0.383048  1.500000
# 4  1.250000  0.559053  0.034450  0.719930  0.421004  1.500000
# 5  1.250000  0.900274  0.669612  0.456069  0.289804  0.525819

# %%
filled_df=df_obj.fillna(method='ffill')
filled_df
# Out:
#           0         1         2         3         4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.411100  0.117376
# 1  0.684969  0.437611  0.556229  0.367080  0.402366  0.117376
# 2  0.447031  0.585445  0.161985  0.520719  0.326051  0.117376
# 3  0.447031  0.836375  0.481343  0.516502  0.383048  0.117376
# 4  0.447031  0.559053  0.034450  0.719930  0.421004  0.117376
# 5  0.447031  0.900274  0.669612  0.456069  0.289804  0.525819

# %% [markdown]
# Counting missing values

# %%
df_obj.loc[3:5,0]=missing
df_obj.loc[1:4,5]=missing
df_obj.isnull().sum()
# Out:
# 0    3
# 1    0
# 2    0
# 3    0
# 4    0
# 5    4
# dtype: int64

# %% [markdown]
# Filtering out missing values

# %%
df_noNA=df_obj.dropna()
df_noNA
# Out:
#           0         1         2         3       4         5
# 0  0.870124  0.582277  0.278839  0.185911  0.4111  0.117376

# %%
df_noNA=df_obj.dropna(axis=1)
df_noNA
# Out:
#           1         2         3         4
# 0  0.582277  0.278839  0.185911  0.411100
# 1  0.437611  0.556229  0.367080  0.402366
# 2  0.585445  0.161985  0.520719  0.326051
# 3  0.836375  0.481343  0.516502  0.383048
# 4  0.559053  0.034450  0.719930  0.421004
# 5  0.900274  0.669612  0.456069  0.289804
